# %% [markdown]
# <a href="https://colab.research.google.com/github/siparatu4-ops/KKASmt1-ratuasyf-X7/blob/main/Aplikasi_sederhana_ratuassyfa_x_7_ipy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aplikasi sederhana

# %%
panjang = int(input("masukan panjang persegi panjang (cm): "))
lebar = int(input("masukan lebar persegi panjang (cm): "))

luas = panjang * lebar

print(f"luas persegi panjang yaitu {luas} cm^2.")
# Out:
# masukan panjang persegi panjang (cm): 5
# masukan lebar persegi panjang (cm): 3
# luas persegi panjang yaitu 15 cm^2.

# %%
pi = 22/7
jari_jari = float(input("Masukan jari jari bola"))

volume = 3/4 * pi * jari_jari**3

print (f"volume dengan jari jari {jari_jari} cm adalah {volume :.2f}")
# Out:
# Masukan jari jari bola14
# volume dengan jari jari 14.0 cm adalah 6468.00
